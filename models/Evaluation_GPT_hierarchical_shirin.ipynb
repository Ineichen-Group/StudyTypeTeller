# %%
import pandas as pd
import json
import time
import matplotlib.pyplot as plt
from tqdm import tqdm  # Import tqdm for the progress bar
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix, accuracy_score, balanced_accuracy_score, classification_report
import seaborn as sns
import numpy as np

# %% [markdown]
# # Evaluate Multi-Class

# %% [markdown]
# ## Load file with predictions

# %%
model = "gpt-3.5-turbo"
annotation_approach = "hierachical" 
prompt_ids_to_eval = ["P1_HIERARCHY", "P2_HIERARCHY"]
prompt_id_to_use_for_binary = "P3"
file_suffix = "_hierarchical"

# %%
# Create the list of prediction columns based on the prompt IDs
prediction_columns = [f'gpt_predictions_{prompt_id}' for prompt_id in prompt_ids_to_eval]
# Specify the basic columns to include in the DataFrame
basic_columns = ['pmid', 'accepted_label', 'multi_label', 'binary_label']
# Combine basic columns with the dynamically generated prediction columns
columns_to_read = basic_columns + prediction_columns

# %%
df = pd.read_csv(f"predictions/{model}_enriched_kw_test_outputs_{prompt_id_to_use_for_binary}_{'_'.join(prompt_ids_to_eval)}{file_suffix}.csv")[columns_to_read]

# %%
df.shape
# Out:
# (534, 6)

# %%
df.head()
# Out:
#        pmid         accepted_label  multi_label  binary_label  \
# 0  32147509  Non-systematic-review            1             0
# 1  16312938  Non-systematic-review            1             0
# 2  23811310  Non-systematic-review            1             0
# 3  27534431              Remaining            0             0
# 4   8291133              Remaining            0             0
#
#   gpt_predictions_P1_HIERARCHY gpt_predictions_P2_HIERARCHY
# 0     Animal-systematic-review     Animal-systematic-review
# 1                 Animal-other                 Animal-other
# 2                 Animal-other                 Animal-other
# 3                 Animal-other                 Animal-other
# 4                 Animal-other                 Animal-other

# %% [markdown]
# ## Map predictions to numerical

# %%
label_to_numerical = {
    'Remaining': 0,
    'Non-systematic-review': 1,
    'Human-non-RCT-non-drug-intervention': 2,
    'Human-non-RCT-drug-intervention': 3,
    'Human-case-report': 4,
    'Animal-other': 5,
    'Animal-drug-intervention': 6,
    'Human-systematic-review': 7,
    'In-vitro-study': 8,
    'Human-RCT-non-drug-intervention': 9,
    'Animal-non-drug-intervention': 10,
    'Human-RCT-drug-intervention': 11,
    'Clinical-study-protocol': 12,
    'Human-RCT-non-intervention': 13
}

# %%
numerical_to_label = {v: f"{v} - {k}" for k, v in label_to_numerical.items()}

# %%
import difflib

def map_label_fuzzy(label, label_dict):
    #label = label.lower().replace('-', '').replace('_', ' ').strip()
    best_match = difflib.get_close_matches(label, label_dict.keys(), n=1, cutoff=0.6)
    if best_match:
        #print(f'{label} matched to {best_match[0]}')
        return label_dict[best_match[0]]
    return -1

# %%
map_label_fuzzy("RCT-drug-intervention", label_to_numerical)
# Out:
# 11

# %%
def map_label_to_numerical(label, label_dict):
    # Check if label is a dictionary
    if isinstance(label, dict):
        # Extract the label with the highest score/probability
        highest_label = max(normalized_label, key=label.get)
        return label_dict.get(highest_label, -1)
    else:
         # Normalize label
        normalized_label = label.replace(',', '').strip().replace(' ', '-')#.strip()
        # Directly map string labels to numerical IDs
        numerical_label = label_dict.get(label, -1)
        # Fuzzy match if no direct mapping possible
        if numerical_label == -1:
            numerical_label = map_label_fuzzy(normalized_label, label_dict)
        # If fuzzy match did not work, check if the label string contains the key 'label' and use it to split the string; keep everything to the right as the potential label
        if numerical_label == -1:
            if 'label' in label:
                label_part = label.split('label')[1]
                numerical_label = map_label_fuzzy(label_part, label_dict)
        return numerical_label
        
# Convert accepted labels to numerical
df['accepted_label_numerical'] = df['accepted_label'].apply(lambda x: map_label_to_numerical(x, label_to_numerical))


for col in prediction_columns:
    df[f'{col}_numerical'] = df[col].apply(lambda x: map_label_to_numerical(x, label_to_numerical))

df.head()
# Out:
#        pmid         accepted_label  multi_label  binary_label  \
# 0  32147509  Non-systematic-review            1             0
# 1  16312938  Non-systematic-review            1             0
# 2  23811310  Non-systematic-review            1             0
# 3  27534431              Remaining            0             0
# 4   8291133              Remaining            0             0
#
#   gpt_predictions_P1_HIERARCHY gpt_predictions_P2_HIERARCHY  \
# 0     Animal-systematic-review     Animal-systematic-review
# 1                 Animal-other                 Animal-other
# 2                 Animal-other                 Animal-other
# 3                 Animal-other                 Animal-other
# 4                 Animal-other                 Animal-other
#
#    accepted_label_numerical  gpt_predictions_P1_HIERARCHY_numerical  \
# 0                         1                                       7
# 1                         1                                       5
# 2                         1                                       5
# 3                         0                                       5
# 4                         0                                       5
#
#    gpt_predictions_P2_HIERARCHY_numerical
# 0                                       7
# 1                                       5
# 2                                       5
# 3                                       5
# 4                                       5

# %% [markdown]
# #### Important: some labels from GPT could not be mapped to a target label

# %%
rows_with_minus_one = df[(df == -1).any(axis=1)]
rows_with_minus_one
# Out:
# Empty DataFrame
# Columns: [pmid, accepted_label, multi_label, binary_label, gpt_predictions_P1_HIERARCHY, gpt_predictions_P2_HIERARCHY, accepted_label_numerical, gpt_predictions_P1_HIERARCHY_numerical, gpt_predictions_P2_HIERARCHY_numerical]
# Index: []

# %% [markdown]
# ## Evaluate prompts

# %%
def evaluate_predictions(df, target_label_col, prompt_ids_to_eval, model, eval_type, label_to_numerical, numerical_to_label):
    report_dfs = []
    summary_stats = []

    for prompt_id in prompt_ids_to_eval:
        print("Evaluating ", prompt_id)
        prediction_col = f'gpt_predictions_{prompt_id}'

        # Extract arrays for evaluation
        y_true = df[target_label_col].values
        y_pred = df[f'{prediction_col}_numerical'].values
        cm = confusion_matrix(y_true, y_pred, labels=range(len(label_to_numerical)))
        
        # Calculate metrics
        accuracy = accuracy_score(y_true, y_pred)
        accuracy_balanced = balanced_accuracy_score(y_true, y_pred)
        report = classification_report(y_true, y_pred, output_dict=True, zero_division=0, labels=range(len(label_to_numerical)), target_names=[numerical_to_label[i] for i in range(len(label_to_numerical))])

        
        # Create DataFrame from report
        report_df = pd.DataFrame(report).transpose()
        report_df['Prompt ID'] = prompt_id
        report_dfs.append(report_df)
        
        # Extract summary statistics
        summary = report_df.loc['weighted avg', ['precision', 'recall', 'f1-score']].to_dict()
        summary['Prompt ID'] = prompt_id
        summary_stats.append(summary)

        # Plotting confusion matrix
        plt.figure(figsize=(10, 6))
        ax = sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(len(label_to_numerical)), yticklabels=range(len(label_to_numerical)))
        ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=13)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=13)
        plt.title(f'Confusion Matrix for Model {model} and Prompt {prompt_id} based on binary prompt {prompt_id_to_use_for_binary}', fontsize=10)
        plt.xlabel('Predicted Labels', fontsize=13)
        plt.ylabel('True Labels', fontsize=13)

        # Add an inset with label mapping
        textstr = '\n'.join([f'{v}: {k}' for k, v in label_to_numerical.items()])
        props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
        ax.text(1.16, 1.0, textstr, transform=ax.transAxes, fontsize=10, verticalalignment='top', bbox=props)
        plt.tight_layout()
        plt.savefig(f'plots/confusion_matrix_{model}_enriched_kw_test_{prompt_id_to_use_for_binary}_{prompt_id}_{eval_type}.pdf')  # Save to PDF
        #plt.savefig(f'plots/confusion_matrix_{model}_enriched_test_{prompt_id_to_use_for_binary}_{prompt_id}_{eval_type}.pdf')  # Save to PDF

    # Combine all report DataFrames
    all_reports_df = pd.concat(report_dfs)

    # Create a summary table for average precision, recall, and F1-score
    summary_df = pd.DataFrame(summary_stats)
    # Save results to CSV files
    all_reports_df.to_csv(f"evaluations/{model}_enriched_kw_test_per_class_{prompt_id_to_use_for_binary}_{'_'.join(prompt_ids_to_eval)}_{eval_type}.csv")
    summary_df.to_csv(f"evaluations/{model}_enriched_kw_test_summary_{prompt_id_to_use_for_binary}_{'_'.join(prompt_ids_to_eval)}_{eval_type}.csv")
    #all_reports_df.to_csv(f"evaluations/{model}_enriched_test_per_class_{prompt_id_to_use_for_binary}_{'_'.join(prompt_ids_to_eval)}_{eval_type}.csv")
    #summary_df.to_csv(f"evaluations/{model}_enriched_test_summary_{prompt_id_to_use_for_binary}_{'_'.join(prompt_ids_to_eval)}_{eval_type}.csv")

    print("Results saved to evaluations/ and plots/ folders.")

    return all_reports_df, summary_df

# %%
target_label_col = 'accepted_label_numerical'
all_reports_df, summary_df = evaluate_predictions(df, target_label_col, prompt_ids_to_eval, model, annotation_approach, label_to_numerical, numerical_to_label)
# Out:
# Evaluating  P1_HIERARCHY
# Evaluating  P2_HIERARCHY
# Results saved to evaluations/ and plots/ folders.

# %%
summary_df
# Out:
#    precision    recall  f1-score     Prompt ID
# 0   0.503929  0.346442  0.294712  P1_HIERARCHY
# 1   0.616915  0.550562  0.540481  P2_HIERARCHY

# %%
all_reports_df
# Out:
#                                          precision    recall  f1-score  \
# 0 - Remaining                             0.464286  0.075581  0.130000
# 1 - Non-systematic-review                 0.857143  0.080000  0.146341
# 2 - Human-non-RCT-non-drug-intervention   0.209302  0.214286  0.211765
# 3 - Human-non-RCT-drug-intervention       0.500000  0.083333  0.142857
# 4 - Human-case-report                     0.330000  1.000000  0.496241
# 5 - Animal-other                          0.500000  0.645161  0.563380
# 6 - Animal-drug-intervention              0.826087  0.633333  0.716981
# 7 - Human-systematic-review               0.134146  1.000000  0.236559
# 8 - In-vitro-study                        0.578947  0.523810  0.550000
# 9 - Human-RCT-non-drug-intervention       0.500000  0.777778  0.608696
# 10 - Animal-non-drug-intervention         0.666667  0.750000  0.705882
# 11 - Human-RCT-drug-intervention          0.608696  0.933333  0.736842
# 12 - Clinical-study-protocol              0.257143  0.750000  0.382979
# 13 - Human-RCT-non-intervention           0.000000  0.000000  0.000000
# accuracy                                  0.346442  0.346442  0.346442
# macro avg                                 0.459458  0.533330  0.402037
# weighted avg                              0.503929  0.346442  0.294712
# 0 - Remaining                             0.640000  0.465116  0.538721
# 1 - Non-systematic-review                 0.782609  0.240000  0.367347
# 2 - Human-non-RCT-non-drug-intervention   0.329268  0.642857  0.435484
# 3 - Human-non-RCT-drug-intervention       0.500000  0.416667  0.454545
# 4 - Human-case-report                     0.400000  0.969697  0.566372
# 5 - Animal-other                          0.523810  0.709677  0.602740
# 6 - Animal-drug-intervention              0.769231  0.666667  0.714286
# 7 - Human-systematic-review               0.633333  0.863636  0.730769
# 8 - In-vitro-study                        0.458333  0.523810  0.488889
# 9 - Human-RCT-non-drug-intervention       0.608696  0.777778  0.682927
# 10 - Animal-non-drug-intervention         0.857143  0.750000  0.800000
# 11 - Human-RCT-drug-intervention          0.583333  0.933333  0.717949
# 12 - Clinical-study-protocol              1.000000  0.666667  0.800000
# 13 - Human-RCT-non-intervention           0.666667  0.181818  0.285714
# accuracy                                  0.550562  0.550562  0.550562
# macro avg                                 0.625173  0.629123  0.584696
# weighted avg                              0.616915  0.550562  0.540481
#
#                                             support     Prompt ID
# 0 - Remaining                            172.000000  P1_HIERARCHY
# 1 - Non-systematic-review                 75.000000  P1_HIERARCHY
# 2 - Human-non-RCT-non-drug-intervention   42.000000  P1_HIERARCHY
# 3 - Human-non-RCT-drug-intervention       36.000000  P1_HIERARCHY
# 4 - Human-case-report                     33.000000  P1_HIERARCHY
# 5 - Animal-other                          31.000000  P1_HIERARCHY
# 6 - Animal-drug-intervention              30.000000  P1_HIERARCHY
# 7 - Human-systematic-review               22.000000  P1_HIERARCHY
# 8 - In-vitro-study                        21.000000  P1_HIERARCHY
# 9 - Human-RCT-non-drug-intervention       18.000000  P1_HIERARCHY
# 10 - Animal-non-drug-intervention         16.000000  P1_HIERARCHY
# 11 - Human-RCT-drug-intervention          15.000000  P1_HIERARCHY
# 12 - Clinical-study-protocol              12.000000  P1_HIERARCHY
# 13 - Human-RCT-non-intervention           11.000000  P1_HIERARCHY
# accuracy                                   0.346442  P1_HIERARCHY
# macro avg                                534.000000  P1_HIERARCHY
# weighted avg                             534.000000  P1_HIERARCHY
# 0 - Remaining                            172.000000  P2_HIERARCHY
# 1 - Non-systematic-review                 75.000000  P2_HIERARCHY
# 2 - Human-non-RCT-non-drug-intervention   42.000000  P2_HIERARCHY
# 3 - Human-non-RCT-drug-intervention       36.000000  P2_HIERARCHY
# 4 - Human-case-report                     33.000000  P2_HIERARCHY
# 5 - Animal-other                          31.000000  P2_HIERARCHY
# 6 - Animal-drug-intervention              30.000000  P2_HIERARCHY
# 7 - Human-systematic-review               22.000000  P2_HIERARCHY
# 8 - In-vitro-study                        21.000000  P2_HIERARCHY
# 9 - Human-RCT-non-drug-intervention       18.000000  P2_HIERARCHY
# 10 - Animal-non-drug-intervention         16.000000  P2_HIERARCHY
# 11 - Human-RCT-drug-intervention          15.000000  P2_HIERARCHY
# 12 - Clinical-study-protocol              12.000000  P2_HIERARCHY
# 13 - Human-RCT-non-intervention           11.000000  P2_HIERARCHY
# accuracy                                   0.550562  P2_HIERARCHY
# macro avg                                534.000000  P2_HIERARCHY
# weighted avg                             534.000000  P2_HIERARCHY
