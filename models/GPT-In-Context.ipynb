# %%
import torch
import numpy as np
from pathlib import Path

from sklearn.metrics.pairwise import pairwise_distances
from sklearn.metrics import pairwise
import pandas as pd
from openai import OpenAI
import openai

from sklearn.metrics import accuracy_score, classification_report, balanced_accuracy_score
from sklearn.metrics import balanced_accuracy_score

import random

# %%
embeddings_data_path = Path("./data/embeddings/")
input_data_path = Path("./data/data_splits_stratified/6-2-2_all_classes/")

# %% [markdown]
# ## Load Embeddings and Calculate Similarities

# %% [markdown]
# ### Load
# -> each row represents the text from one sample embedded into a 768-demnsional vector

# %%
embeddings_train = np.load(
    embeddings_data_path / "embeddings_microsoft_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext_train_ds.npy"
)
embeddings_test = np.load(
    embeddings_data_path / "embeddings_microsoft_BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext_test_ds.npy"
)

# %%
embeddings_train.shape
# Out:
# (1191, 768)

# %%
embeddings_test.shape
# Out:
# (404, 768)

# %% [markdown]
# ### Compute similarity between test dataset elements to all train elements

# %%
dist_matrix = pairwise_distances(embeddings_test, embeddings_train, metric='sqeuclidean')
dist_matrix.shape
# Out:
# (404, 1191)

# %%
dist_matrix_cosine = pairwise.cosine_similarity(X=embeddings_test, Y=embeddings_train)
dist_matrix.shape
# Out:
# (404, 1191)

# %% [markdown]
# The matrix has the dimensions 404 (test data elements) x 1191 (train data elements). Each of the 1191 values per test row is the similarity score between the test element to the train elements.

# %%
dist_matrix_cosine
# Out:
# array([[0.98506499, 0.98830865, 0.98870777, ..., 0.98741564, 0.98696952,
#         0.98295794],
#        [0.99007619, 0.99129481, 0.9916276 , ..., 0.99085124, 0.99138424,
#         0.98798618],
#        [0.98900018, 0.99066293, 0.9915621 , ..., 0.98766824, 0.99073964,
#         0.98834762],
#        ...,
#        [0.98882802, 0.9873871 , 0.98857115, ..., 0.9928928 , 0.98869445,
#         0.98763254],
#        [0.98709908, 0.987791  , 0.9864768 , ..., 0.9930578 , 0.98749872,
#         0.98896695],
#        [0.98904398, 0.98862152, 0.98700841, ..., 0.9863798 , 0.99105832,
#         0.99154065]])

# %% [markdown]
# ### Find closest neighbours from the train dataset to each test example

# %%
values, indices = torch.topk(-torch.from_numpy(dist_matrix_cosine), k=3, dim=-1)

# %%
indices.shape
# Out:
# torch.Size([404, 3])

# %% [markdown]
# The indices have the dimension 404 (test data elements) x 3 (top k=3 closest train data elements).

# %%
indices
# Out:
# tensor([[ 128, 1032,  413],
#         [ 128, 1032,  413],
#         [ 128,  413, 1032],
#         ...,
#         [ 128,   11, 1032],
#         [  11,  128,  356],
#         [ 128,  356, 1032]])

# %%
df_train = pd.read_csv(input_data_path/ 'train.csv')
df_test = pd.read_csv(input_data_path/ 'test.csv')

# %%
df_test[df_test['accepted_label'] == 'In-vitro-study']
# Out:
#      idx      pmid                                       journal_name  \
# 245  246  27983922                                  Oncology research
# 246  247  16332401                              Neurobiology of aging
# 247  248  14655759              Brain pathology (Zurich, Switzerland)
# 248  249   8297640                                APMIS. Supplementum
# 249  250  19630956                                    Molecular brain
# 250  251  25413246                               Cell transplantation
# 251  252  21055392  Biochemical and biophysical research communica...
# 252  253  16696567                    Chemical research in toxicology
# 253  254  22363216                                      PLoS genetics
# 254  255  25960208  Biomedicine & pharmacotherapy = Biomedecine & ...
# 255  256  19701582      Sheng li xue bao : [Acta physiologica Sinica]
#
#                                                  title  \
# 245  Overexpression of Protease Serine 8 Inhibits G...
# 246  Increased cholesterol in Abeta-positive nerve ...
# 247  TRAIL triggers apoptosis in human malignant gl...
# 248  Fetal antigen 2 (FA2): the aminopropeptide of ...
# 249  Regulation of endosomal motility and degradati...
# 250  Human umbilical cord blood cells induce neurop...
# 251  In yeast redistribution of Sod1 to the mitocho...
# 252  Ebselen induced C6 glioma cell death in oxygen...
# 253  GTPase activity and neuronal toxicity of Parki...
# 254  miR-25 promotes glioma cell proliferation by t...
# 255  [Cerebral lymphatic blockage aggravates apopto...
#
#                                               abstract  accepted_label  \
# 245  Protease serine 8 (PRSS8), a serine peptidase,...  In-vitro-study
# 246  Synapse loss in Alzheimer's disease (AD) is po...  In-vitro-study
# 247  Many malignant glioma cells express death rece...  In-vitro-study
# 248  Fetal antigen 2 (FA2) was purified from second...  In-vitro-study
# 249  Dysfunction of alsin, particularly its putativ...  In-vitro-study
# 250  Human umbilical cord blood (HUCB) cell therapi...  In-vitro-study
# 251  The antioxidative enzyme copper-zinc superoxid...  In-vitro-study
# 252  Studies have shown that ebselen is an antiinfl...  In-vitro-study
# 253  Mutations in the leucine-rich repeat kinase 2 ...  In-vitro-study
# 254  MicroRNAs (miRNA) have oncogenic or tumor-supp...  In-vitro-study
# 255  This work was performed to determine the role ...  In-vitro-study
#
#      multi_label  binary_label  \
# 245            8             0
# 246            8             0
# 247            8             0
# 248            8             0
# 249            8             0
# 250            8             0
# 251            8             0
# 252            8             0
# 253            8             0
# 254            8             0
# 255            8             0
#
#                           input_journal_title_abstract  \
# 245  <journal>Oncology research</journal><title>Ove...
# 246  <journal>Neurobiology of aging</journal><title...
# 247  <journal>Brain pathology (Zurich, Switzerland)...
# 248  <journal>APMIS. Supplementum</journal><title>F...
# 249  <journal>Molecular brain</journal><title>Regul...
# 250  <journal>Cell transplantation</journal><title>...
# 251  <journal>Biochemical and biophysical research ...
# 252  <journal>Chemical research in toxicology</jour...
# 253  <journal>PLoS genetics</journal><title>GTPase ...
# 254  <journal>Biomedicine & pharmacotherapy = Biome...
# 255  <journal>Sheng li xue bao : [Acta physiologica...
#
#                             gpt_predictions_in_context
# 245       {\n  "gpt_label": "Non-systematic-review"\n}
# 246       {\n  "gpt_label": "Non-systematic-review"\n}
# 247       {\n  "gpt_label": "Non-systematic-review"\n}
# 248                   {\n  "gpt_label": "Remaining"\n}
# 249                 {\n    "gpt_label": "Remaining"\n}
# 250  {\n  "gpt_label": "Human-non-RCT-non-drug-inte...
# 251       {\n  "gpt_label": "Non-systematic-review"\n}
# 252       {\n  "gpt_label": "Non-systematic-review"\n}
# 253                   {\n  "gpt_label": "Remaining"\n}
# 254  {\n  "gpt_label": "Human-non-RCT-non-drug-inte...
# 255       {\n  "gpt_label": "Non-systematic-review"\n}

# %%
df_test.iloc[246]
# Out:
# idx                                                                           247
# pmid                                                                     16332401
# journal_name                                                Neurobiology of aging
# title                           Increased cholesterol in Abeta-positive nerve ...
# abstract                        Synapse loss in Alzheimer's disease (AD) is po...
# accepted_label                                                     In-vitro-study
# multi_label                                                                     8
# binary_label                                                                    0
# input_journal_title_abstract    <journal>Neurobiology of aging</journal><title...
# gpt_predictions_in_context           {\n  "gpt_label": "Non-systematic-review"\n}
# Name: 246, dtype: object

# %%
indices[246]
# Out:
# tensor([ 128,  356, 1032])

# %%
df_train.iloc[1032]
# Out:
# idx                                                                          1033
# pmid                                                                     28764897
# journal_name                                                    Atencion primaria
# title                           [Clinical characteristics of patients with atr...
# abstract                        To analyse the clinical characteristics and ma...
# accepted_label                                    Human-non-RCT-drug-intervention
# multi_label                                                                     3
# binary_label                                                                    0
# input_journal_title_abstract    <journal>Atencion primaria</journal><title>[Cl...
# Name: 1032, dtype: object

# %%
df_test.groupby('accepted_label').size()
# Out:
# accepted_label
# Animal-drug-intervention                20
# Animal-non-drug-intervention             6
# Animal-other                            21
# Clinical-study-protocol                  2
# Human-RCT-drug-intervention              5
# Human-RCT-non-drug-intervention          8
# Human-RCT-non-intervention               1
# Human-case-report                       23
# Human-non-RCT-drug-intervention         26
# Human-non-RCT-non-drug-intervention     32
# Human-systematic-review                 12
# In-vitro-study                          11
# Non-systematic-review                   65
# Remaining                              172
# dtype: int64

# %% [markdown]
# ## Init OpenAI API

# %%
def load_pass(file_path, key_to_find):
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split("=")
            if len(parts) == 2 and parts[0] == key_to_find:
                found_password = parts[1]
                break
    if found_password:
        print("Found password.")
        return found_password
    else:
        print("Password not found for key:", key_to_find)

# %%
openai.api_key = load_pass("./credentials.txt", "OPENAI")
client = OpenAI(api_key=openai.api_key)

# %% [markdown]
# ## Create Prompts

# %%
df_train['input_journal_title_abstract'] = '<journal>' + df_train['journal_name'] + '</journal>' + \
                                         '<title>' + df_train['title'] + '</title>' + \
                                         '<abstract>' + df_train['abstract'] + '</abstract>'
df_test['input_journal_title_abstract'] = '<journal>' + df_test['journal_name'] + '</journal>' + \
                                         '<title>' + df_test['title'] + '</title>' + \
                                         '<abstract>' + df_test['abstract'] + '</abstract>'

# %%
df_test
# Out:
#      idx      pmid                                       journal_name  \
# 0      1  15055442  Journal of neuropathology and experimental neu...
# 1      2  11172874                     Journal of affective disorders
# 2      3  19961324                        Annual review of entomology
# 3      4  11077858  Rozhledy v chirurgii : mesicnik Ceskoslovenske...
# 4      5  20362421  Archives de pediatrie : organe officiel de la ...
# ..   ...       ...                                                ...
# 399  400  37550718                                             Trials
# 400  401  11279969                                           Headache
# 401  402  33393402                  Developmental neurorehabilitation
# 402  403  32541457                                           Medicine
# 403  404   9109029               Journal of abnormal child psychology
#
#                                                  title  \
# 0    Emerging tumor entities and variants of CNS ne...
# 1    Serotonergic gene expression and depression: i...
# 2    Ekbom syndrome: the challenge of 'invisible bu...
# 3                                    [Brain injuries].
# 4                   [Treatment of childhood dystonia].
# ..                                                 ...
# 399  Can dexamethasone improve postoperative sleep ...
# 400  Intranasal lidocaine for migraine: a randomize...
# 401  Lower Limb Sensorimotor Training (LoSenseT) fo...
# 402  Association between non-alcoholic fatty liver ...
# 403  Psychiatric disorders associated with substanc...
#
#                                               abstract  \
# 0    Since the appearance in 2000 of the World Heal...
# 1    The development and configuration of several n...
# 2    Ekbom Syndrome is synonymous with delusory par...
# 3    The author presents an account of contemporary...
# 4    Dystonia is not uncommon in childhood, but is ...
# ..                                                 ...
# 399  Perioperative sleep disorders (PSD) are an ind...
# 400  To study the efficacy of intranasal lidocaine ...
# 401  Motor disorders in cerebral palsy (CP) are oft...
# 402  This study will systematically synthesize the ...
# 403  The relationships between specific quantities ...
#
#                   accepted_label  multi_label  binary_label  \
# 0          Non-systematic-review            1             0
# 1          Non-systematic-review            1             0
# 2          Non-systematic-review            1             0
# 3          Non-systematic-review            1             0
# 4          Non-systematic-review            1             0
# ..                           ...          ...           ...
# 399  Human-RCT-drug-intervention           11             0
# 400  Human-RCT-drug-intervention           11             0
# 401      Clinical-study-protocol           12             0
# 402      Clinical-study-protocol           12             0
# 403   Human-RCT-non-intervention           13             0
#
#                           input_journal_title_abstract
# 0    <journal>Journal of neuropathology and experim...
# 1    <journal>Journal of affective disorders</journ...
# 2    <journal>Annual review of entomology</journal>...
# 3    <journal>Rozhledy v chirurgii : mesicnik Cesko...
# 4    <journal>Archives de pediatrie : organe offici...
# ..                                                 ...
# 399  <journal>Trials</journal><title>Can dexamethas...
# 400  <journal>Headache</journal><title>Intranasal l...
# 401  <journal>Developmental neurorehabilitation</jo...
# 402  <journal>Medicine</journal><title>Association ...
# 403  <journal>Journal of abnormal child psychology<...
#
# [404 rows x 9 columns]

# %%
def create_prompt(df_train, df_test, test_index, example_indices):
    # Start the prompt with a task description (optional)
    prompt = "Classify this text, choosing one of these labels: Clinical-study-protocol, Human-systematic-review, Non-systematic-review, Human-RCT-non-drug-intervention, Human-RCT-drug-intervention, Human-RCT-non-intervention, Human-case-report, Human-non-RCT-non-drug-intervention, Human-non-RCT-drug-intervention, Animal-systematic-review, Animal-drug-intervention, Animal-non-drug-intervention, Animal-other, In-vitro-study, Remaining. Respond in json format with the key: gpt_label.\n\n"
    
    # Add examples from df_train
    for idx in example_indices:
        example_text = df_train.loc[idx, 'input_journal_title_abstract']
        example_label = df_train.loc[idx, 'accepted_label']
        prompt += f"Text: \"{example_text}\"\nCategory: {example_label}\n\n"
    
    # Add the test text needing classification
    test_text = df_test.loc[test_index, 'input_journal_title_abstract']
    prompt += f"Text: \"{test_text}\"\nCategory: "
    
    return prompt

# %%
example_i = 0
example_prompt = create_prompt(df_train, df_test, example_i, indices[example_i].tolist())
#example_prompt

# %%
len(example_prompt.split())
# Out:
# 1483

# %%
query_gpt(example_prompt)
# Out:
# Trying to call OpenAI API...
# '{\n    "gpt_label": "Non-systematic-review"\n}'

# %%
import time
from tqdm.auto import tqdm

DEFAULT_TEMPERATURE = 0

def create_prompt(df_train, example_indices, input_raw_text):
    prompt = "Classify this text, choosing one of these labels: Clinical-study-protocol, Human-systematic-review, Non-systematic-review, Human-RCT-non-drug-intervention, Human-RCT-drug-intervention, Human-RCT-non-intervention, Human-case-report, Human-non-RCT-non-drug-intervention, Human-non-RCT-drug-intervention, Animal-systematic-review, Animal-drug-intervention, Animal-non-drug-intervention, Animal-other, In-vitro-study, Remaining. Respond in json format with the key: gpt_label.\n\n"
    for idx in example_indices:
        example_text = df_train.loc[idx, 'input_journal_title_abstract']
        example_label = df_train.loc[idx, 'accepted_label']
        prompt += f"Text: \"{example_text}\"\nCategory: {example_label}\n\n"
    prompt += f"Text: \"{input_raw_text}\"\nCategory: "
    return prompt

def query_gpt(df_train, input_raw_text, example_indices, gpt_model="gpt-3.5-turbo", temperature=DEFAULT_TEMPERATURE, max_retries=5, retry_delay=3):
    prompt_text = create_prompt(df_train, example_indices, input_raw_text)
    system_msg = f"You are an expert assistant specialized in text classification of PubMed abstracts."

    retries = 0
    while retries < max_retries:
        print("Trying to call OpenAI API...")
        try:
            completion = client.chat.completions.create(
                model=gpt_model,  
                response_format={"type": "json_object"},
                temperature=temperature,
                messages=[
                    {"role": "system", "content": system_msg},
                    {"role": "user", "content": prompt_text}
                ]
            )
            return completion.choices[0].message.content
        except Exception as e:
            print(f"OpenAI API returned an error: {e}")
            time.sleep(retry_delay)
            retries += 1

    raise RuntimeError("Max retries reached. Unable to complete the API call.")

def apply_gpt_with_progress(df_train, test_data_series, example_indices_tensor=None, num_samples=3, use_random=False, model="gpt-3.5-turbo"):
    results = []
    total_items = len(test_data_series)
    with tqdm(total=total_items, desc="Processing dataset") as pbar:
        for i, text in enumerate(test_data_series):
            if use_random:
                example_indices = random.sample(range(len(df_train)), num_samples)
            else:
                example_indices = example_indices_tensor[i].tolist()
            print("Retrieved in-context learning examples with idx: ", example_indices)
            result = query_gpt(df_train, text, example_indices, model)
            results.append(result)
            pbar.update(1)
    return results

# %%
# Example usage:
df_test[f'gpt_predictions_in_context'] = apply_gpt_with_progress(df_train, df_test['input_journal_title_abstract'], indices)
# Out:
# Processing dataset:   0%|          | 0/404 [00:00<?, ?it/s]
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [413, 356, 128]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 128, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 128, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [413, 1032, 128]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 984, 65]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 697, 990]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 128, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 128, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [413, 128, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 128, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [413, 128, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 11, 128]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 128, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [1032, 128, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 128, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 66]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 1114]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 128, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 697, 990]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 128, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1000]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 11, 128]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 128, 739]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 128, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 1000]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 65, 739]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [11, 128, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 128, 4]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 4]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 128, 140]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [11, 356, 128]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [413, 356, 128]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 841]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [191, 11, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 191]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [413, 356, 128]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 1032]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 413, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 11, 356]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 1032, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [356, 128, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 356, 413]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [128, 191,

# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [838, 317, 1071]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [130, 423, 744]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [122, 362, 999]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [392, 776, 644]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [300, 78, 246]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [585, 878, 11]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [621, 194, 76]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [190, 992, 1181]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [1009, 363, 88]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [494, 674, 137]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [211, 842, 1142]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [858, 625, 19]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [849, 87, 336]
# Trying to call OpenAI API...
# Retrieved in-context learning examples with idx:  [670, 1177, 993]
# Trying to call OpenAI API...

# %% [markdown]
# ## Evaluate

# %%
df_test_to_eval = df_test.copy()
df_test_to_eval.head()
# Out:
#    idx      pmid                                       journal_name  \
# 0    1  15055442  Journal of neuropathology and experimental neu...
# 1    2  11172874                     Journal of affective disorders
# 2    3  19961324                        Annual review of entomology
# 3    4  11077858  Rozhledy v chirurgii : mesicnik Ceskoslovenske...
# 4    5  20362421  Archives de pediatrie : organe officiel de la ...
#
#                                                title  \
# 0  Emerging tumor entities and variants of CNS ne...
# 1  Serotonergic gene expression and depression: i...
# 2  Ekbom syndrome: the challenge of 'invisible bu...
# 3                                  [Brain injuries].
# 4                 [Treatment of childhood dystonia].
#
#                                             abstract         accepted_label  \
# 0  Since the appearance in 2000 of the World Heal...  Non-systematic-review
# 1  The development and configuration of several n...  Non-systematic-review
# 2  Ekbom Syndrome is synonymous with delusory par...  Non-systematic-review
# 3  The author presents an account of contemporary...  Non-systematic-review
# 4  Dystonia is not uncommon in childhood, but is ...  Non-systematic-review
#
#    multi_label  binary_label  \
# 0            1             0
# 1            1             0
# 2            1             0
# 3            1             0
# 4            1             0
#
#                         input_journal_title_abstract  \
# 0  <journal>Journal of neuropathology and experim...
# 1  <journal>Journal of affective disorders</journ...
# 2  <journal>Annual review of entomology</journal>...
# 3  <journal>Rozhledy v chirurgii : mesicnik Cesko...
# 4  <journal>Archives de pediatrie : organe offici...
#
#                           gpt_predictions_in_context  \
# 0       {\n  "gpt_label": "Non-systematic-review"\n}
# 1       {\n  "gpt_label": "Non-systematic-review"\n}
# 2       {\n  "gpt_label": "Non-systematic-review"\n}
# 3       {\n  "gpt_label": "Non-systematic-review"\n}
# 4  {\n  "gpt_label": "Human-non-RCT-non-drug-inte...
#
#                    gpt_predictions_in_context_random
# 0                   {\n  "gpt_label": "Remaining"\n}
# 1       {\n  "gpt_label": "Non-systematic-review"\n}
# 2  {\n    "gpt_label": "Human-non-RCT-non-drug-in...
# 3       {\n  "gpt_label": "Non-systematic-review"\n}
# 4                   {\n  "gpt_label": "Remaining"\n}

# %%
prompt_ids_to_test = ["in_context", "in_context_random"]

# %%
labels = ["Human-systematic-review", "Human-RCT-drug-intervention", "Human-RCT-non-drug-intervention", "Human-RCT-non-intervention", "Human-case-report", "Human-non-RCT-drug-intervention", "Human-non-RCT-non-drug-intervention", "Animal-systematic-review", "Animal-drug-intervention", "Animal-non-drug-intervention", "Animal-other", "Non-systematic-review", "In-vitro-study", "Clinical-study-protocol", "Remaining"]

label_to_numerical = {label: i for i, label in enumerate(labels)}
label_to_numerical["label missing"] = -1

# %%
def map_label_to_numerical(label):
    # Check if label is a dictionary
    if isinstance(label, dict):
        # Extract the label with the highest score/probability
        highest_label = max(label, key=label.get)
        return label_to_numerical.get(highest_label, -1)
    else:
        # Directly map string labels to numerical IDs
        return label_to_numerical.get(label, -1)
        
# Convert accepted labels to numerical
df_test_to_eval['accepted_label_numerical'] = df_test_to_eval['accepted_label'].apply(lambda x: label_to_numerical.get(x, -1))


# Initialize a list to hold DataFrame for each report and summary statistics
report_dfs = []
summary_stats = []

# Iterate over each GPT prediction column
for prompt_id in prompt_ids_to_test:
    print("Evaluating ", prompt_id)
    prediction_col = f'gpt_predictions_{prompt_id}_clean'

    df_test_to_eval[prediction_col] = df_test_to_eval[f'gpt_predictions_{prompt_id}'].apply(
            lambda x: json.loads(x)['gpt_label'] if isinstance(x, str) and 'gpt_label' in json.loads(x) else x
        )
    
    # Map GPT predictions to numerical values
    df_test_to_eval[f'{prediction_col}_numerical'] = df_test_to_eval[prediction_col].apply(map_label_to_numerical)
    
    # Extract arrays for evaluation
    y_true = df_test_to_eval['accepted_label_numerical'].values
    y_pred = df_test_to_eval[f'{prediction_col}_numerical'].values
    
    # Calculate metrics
    accuracy = accuracy_score(y_true, y_pred)
    accuracy_balanced = balanced_accuracy_score(y_true, y_pred)
    report = classification_report(y_true, y_pred, output_dict=True, zero_division=0, labels=range(len(labels)), target_names=labels)
    
    # Create DataFrame from report
    report_df = pd.DataFrame(report).transpose()
    report_df['Prompt ID'] = prompt_id  # Add column to indicate the prompt ID
    report_dfs.append(report_df)
    
    # Extract summary statistics (average precision, recall, F1)
    summary = report_df.loc['weighted avg', ['precision', 'recall', 'f1-score']].to_dict()
    summary['Prompt ID'] = prompt_id
    summary_stats.append(summary)

# Combine all report DataFrames
all_reports_df = pd.concat(report_dfs)

# Create a summary table for average precision, recall, and F1-score
summary_df = pd.DataFrame(summary_stats)
# Out:
# Evaluating  in_context
# Evaluating  in_context_random
# /opt/anaconda3/envs/studytype-teller/lib/python3.12/site-packages/sklearn/metrics/_classification.py:2458: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")

# %%
all_reports_df
# Out:
#                                      precision    recall  f1-score    support  \
# Human-systematic-review               0.750000  0.250000  0.375000   12.00000
# Human-RCT-drug-intervention           1.000000  0.200000  0.333333    5.00000
# Human-RCT-non-drug-intervention       0.000000  0.000000  0.000000    8.00000
# Human-RCT-non-intervention            0.000000  0.000000  0.000000    1.00000
# Human-case-report                     0.468750  0.652174  0.545455   23.00000
# Human-non-RCT-drug-intervention       0.000000  0.000000  0.000000   26.00000
# Human-non-RCT-non-drug-intervention   0.142857  0.125000  0.133333   32.00000
# Animal-systematic-review              0.000000  0.000000  0.000000    0.00000
# Animal-drug-intervention              0.400000  0.100000  0.160000   20.00000
# Animal-non-drug-intervention          1.000000  0.166667  0.285714    6.00000
# Animal-other                          0.000000  0.000000  0.000000   21.00000
# Non-systematic-review                 0.144330  0.646154  0.235955   65.00000
# In-vitro-study                        0.000000  0.000000  0.000000   11.00000
# Clinical-study-protocol               0.333333  0.500000  0.400000    2.00000
# Remaining                             0.343750  0.063953  0.107843  172.00000
# accuracy                              0.198020  0.198020  0.198020    0.19802
# macro avg                             0.305535  0.180263  0.171776  404.00000
# weighted avg                          0.278529  0.198020  0.154899  404.00000
# Human-systematic-review               0.357143  0.416667  0.384615   12.00000
# Human-RCT-drug-intervention           0.250000  0.200000  0.222222    5.00000
# Human-RCT-non-drug-intervention       0.000000  0.000000  0.000000    8.00000
# Human-RCT-non-intervention            0.000000  0.000000  0.000000    1.00000
# Human-case-report                     0.414634  0.739130  0.531250   23.00000
# Human-non-RCT-drug-intervention       0.187500  0.115385  0.142857   26.00000
# Human-non-RCT-non-drug-intervention   0.081633  0.125000  0.098765   32.00000
# Animal-systematic-review              0.000000  0.000000  0.000000    0.00000
# Animal-drug-intervention              0.227273  0.250000  0.238095   20.00000
# Animal-non-drug-intervention          0.000000  0.000000  0.000000    6.00000
# Animal-other                          0.172414  0.238095  0.200000   21.00000
# Non-systematic-review                 0.209302  0.138462  0.166667   65.00000
# In-vitro-study                        0.000000  0.000000  0.000000   11.00000
# Clinical-study-protocol               0.333333  0.500000  0.400000    2.00000
# Remaining                             0.473684  0.470930  0.472303  172.00000
# micro avg                             0.324257  0.324257  0.324257  404.00000
# macro avg                             0.180461  0.212911  0.190452  404.00000
# weighted avg                          0.313046  0.324257  0.313494  404.00000
#
#                                              Prompt ID
# Human-systematic-review                     in_context
# Human-RCT-drug-intervention                 in_context
# Human-RCT-non-drug-intervention             in_context
# Human-RCT-non-intervention                  in_context
# Human-case-report                           in_context
# Human-non-RCT-drug-intervention             in_context
# Human-non-RCT-non-drug-intervention         in_context
# Animal-systematic-review                    in_context
# Animal-drug-intervention                    in_context
# Animal-non-drug-intervention                in_context
# Animal-other                                in_context
# Non-systematic-review                       in_context
# In-vitro-study                              in_context
# Clinical-study-protocol                     in_context
# Remaining                                   in_context
# accuracy                                    in_context
# macro avg                                   in_context
# weighted avg                                in_context
# Human-systematic-review              in_context_random
# Human-RCT-drug-intervention          in_context_random
# Human-RCT-non-drug-intervention      in_context_random
# Human-RCT-non-intervention           in_context_random
# Human-case-report                    in_context_random
# Human-non-RCT-drug-intervention      in_context_random
# Human-non-RCT-non-drug-intervention  in_context_random
# Animal-systematic-review             in_context_random
# Animal-drug-intervention             in_context_random
# Animal-non-drug-intervention         in_context_random
# Animal-other                         in_context_random
# Non-systematic-review                in_context_random
# In-vitro-study                       in_context_random
# Clinical-study-protocol              in_context_random
# Remaining                            in_context_random
# micro avg                            in_context_random
# macro avg                            in_context_random
# weighted avg                         in_context_random

# %%
summary_df
# Out:
#    precision    recall  f1-score          Prompt ID
# 0   0.278529  0.198020  0.154899         in_context
# 1   0.313046  0.324257  0.313494  in_context_random

# %%
print(summary_df)
# Out:
#    precision    recall  f1-score          Prompt ID
# 0   0.278529  0.198020  0.154899         in_context
# 1   0.313046  0.324257  0.313494  in_context_random
